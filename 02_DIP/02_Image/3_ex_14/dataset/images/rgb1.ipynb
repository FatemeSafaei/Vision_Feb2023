# %%
import cv2
import matplotlib.pyplot as plt

# %%
a = cv2.imread('a.jpg',cv2.IMREAD_UNCHANGED)
c = cv2.imread('c.jpg',cv2.IMREAD_UNCHANGED)
d = cv2.imread('d.png',cv2.IMREAD_UNCHANGED)
e = cv2.imread('e.jpg',cv2.IMREAD_UNCHANGED)

# %%
a.shape
# Out:
# (320, 480)

# %%
c.shape
# Out:
# (512, 512)

# %%
d.shape
# Out:
# (316, 314)

# %%
e.shape
# Out:
# (600, 600)

# %%
ret,aa = cv2.threshold(a,70,255,0)
plt.imshow(aa, cmap='gray')
aa.shape
# Out:
# (320, 480)

# %%
ret,cc = cv2.threshold(c,70,255,0)
plt.imshow(cc, cmap='gray')
cc.shape
# Out:
# (512, 512)

# %%
ret,dd = cv2.threshold(d,70,255,0)
plt.imshow(dd, cmap='gray')
dd.shape
# Out:
# (316, 314)

# %%
ret,ee = cv2.threshold(e,70,255,0)
plt.imshow(ee, cmap='gray')
ee.shape
# Out:
# (600, 600)

# %%
d.ndim
# Out:
# 2

# %%
import numpy as np 
np.unique(d)
# Out:
# array([ 21,  26,  28,  29,  49,  55,  67,  75,  76,  92, 100, 109, 113,
#        114, 128, 134, 138, 139, 147, 148, 150, 158, 159, 160, 173, 175,
#        178, 184, 189, 195, 196, 200, 202, 206, 210, 212, 215, 216, 219,
#        224, 231, 232, 236, 243, 249, 251, 255], dtype=uint8)

# %%
th, dst = cv2.threshold(d, 120, 255, cv2.THRESH_BINARY);

# %%
np.unique(dst)
# Out:
# array([  0, 255], dtype=uint8)
