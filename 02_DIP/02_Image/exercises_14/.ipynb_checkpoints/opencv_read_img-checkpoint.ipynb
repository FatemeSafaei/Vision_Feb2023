# %%
import cv2
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread('dataset/images/a.jpg')

# %%
plt.imshow(img1)

# %%
img1.shape
# Out:
# (320, 480, 3)

# %%
img2 = cv2.imread('dataset/images/a.jpg', cv2.IMREAD_UNCHANGED)

# %%
img2.shape
# Out:
# (320, 480)

# %%
img3 = cv2.imread('dataset/images/b.jpg')
plt.imshow(img3)

# %%
img3.shape
# Out:
# (320, 480, 3)

# %%
img4 = cv2.imread('dataset/images/b.jpg', cv2.IMREAD_UNCHANGED)
img4.shape
# Out:
# (320, 480, 3)

# %%
channels = img4.shape[2]
channels
# Out:
# 3

# %%
i  = len(img2.shape)
if i == 2 :
    print('gray or binary! with 1 channel!')
elif i == 3:
    j = img2.shape[2]
    print('it is color image with ', j, 'channels')
# Out:
# gray or binary! with 1 channel!
